# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('RAM PASS.jpg')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 6
#       3 import matplotlib.pyplot as plt
#       5 image = cv2.imread('RAM PASS.jpg')
# ----> 6 gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       7 plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#       8 plt.title('Original Image')
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('RAM PASS.jpg')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 6
#       3 import matplotlib.pyplot as plt
#       5 image = cv2.imread('RAM PASS.jpg')
# ----> 6 gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       7 plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#       8 plt.title('Original Image')
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('RAMPASS.jpg')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(401.5), np.float64(647.5), np.float64(-0.5))

# %%
sobel_x = cv2.Sobel(gray_image, cv2.CV_64F, 1, 0, ksize=5) 
sobel_y = cv2.Sobel(gray_image, cv2.CV_64F, 0, 1, ksize=5)  
sobel_combined = cv2.magnitude(sobel_x, sobel_y)  
plt.imshow(sobel_combined, cmap='gray')
plt.title('Sobel Edge Detection')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(401.5), np.float64(647.5), np.float64(-0.5))

# %%
laplacian = cv2.Laplacian(gray_image, cv2.CV_64F)
plt.imshow(laplacian, cmap='gray')
plt.title('Laplacian Edge Detection')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(401.5), np.float64(647.5), np.float64(-0.5))

# %%
canny_edges = cv2.Canny(gray_image, 50, 150)
plt.imshow(canny_edges, cmap='gray')
plt.title('Canny Edge Detection')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(401.5), np.float64(647.5), np.float64(-0.5))
